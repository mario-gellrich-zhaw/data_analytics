# %% [markdown]
# # Image segmentation using k-means clustering

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Current working directory
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: u:\Lektionen\GitHub_Repositories\data_analytics\WTYK\LC_10

# %% [markdown]
# ## Image segmentation

# %% [markdown]
# ### Read the image

# %%
# Read the image

 
# Change the color to RGB (from BGR)


# Plot the image

# %% [markdown]
# ### Reshape the image into a 2D array of pixels and RGB colors

# %%
# Reshaping the image into a 2D array of pixels and RGB colors

 
# Convert to float
# Out:
# array([[ 35.,  79., 152.],
#        [ 36.,  80., 153.],
#        [ 36.,  80., 153.],
#        ...,
#        [ 46.,  36.,   9.],
#        [ 64.,  54.,  27.],
#        [ 57.,  50.,  22.]], dtype=float32)

# %% [markdown]
# ### Use the Elbow method to find the optimal number of clusters k for image segmentation

# %%
# Sum of squared distances of samples to their closest cluster center


# Range of k's


# Loop to find the optimal k

    
# Elbow plot

# %% [markdown]
# ### Perform image segmentation

# %%
# Number of clusters


# Criteria for the segmentation algorithm to stop running

 
# Perform k-means clustering


# Print cluster labels


# Print cluster centroids
# Out:
# Cluster labels:
# [[0]
#  [0]
#  [0]
#  ...
#  [4]
#  [4]
#  [4]]
#
# Centroids of 5 clusters
# [[ 67.530014 113.82899  170.58554 ]
#  [182.58049  150.43794   71.71518 ]
#  [117.33559   98.82832   36.116245]
#  [160.65706  173.99883  178.82549 ]
#  [ 57.319275  51.04073   16.338558]]

# %% [markdown]
# ### Visualize the result

# %%
# Convert data into 8-bit values

 
# Reshape data into the original image dimensions


# Show result

# %% [markdown]
# #### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2024-11-18 12:51:51
# Python Version: 3.11.9
# -----------------------------------
