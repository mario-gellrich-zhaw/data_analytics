# %% [markdown]
# # Image segmentation using k-means clustering

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Current working directory
print('Current working directory:', os.getcwd())

# %% [markdown]
# ## Image segmentation

# %% [markdown]
# ### Read the image

# %%
# Read the image

 
# Change the color to RGB (from BGR)


# Plot the image

# %% [markdown]
# ### Reshape the image into a 2D array of pixels and RGB colors

# %%
# Reshaping the image into a 2D array of pixels and RGB colors

 
# Convert to float

# %% [markdown]
# ### Use the Elbow method to find the optimal number of clusters k for image segmentation

# %%
# Sum of squared distances of samples to their closest cluster center


# Range of k's


# Loop to find the optimal k

    
# Print the k -> distortion values so you can justify your chosen k below


# Elbow plot

# %% [markdown]
# **Image used:** *[which image did you use?]*
#
# **Chosen k:** *[state the k where your distortion curve visibly bends/flattens, using the values you printed above, and why]*

# %% [markdown]
# ### Perform image segmentation

# %%
# Number of clusters


# Criteria for the segmentation algorithm to stop running

 
# Perform k-means clustering


# Print cluster labels


# Print cluster centroids

# %% [markdown]
# ### Visualize the result

# %%
# Convert data into 8-bit values

 
# Reshape data into the original image dimensions


# Show result

# %% [markdown]
# #### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
