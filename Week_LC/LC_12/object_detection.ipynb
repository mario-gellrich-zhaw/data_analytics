# %% [markdown]
# # Object Detection with a Lightweight Neural Network (MobileNet-SSD)

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import cv2
import numpy as np
import requests
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Current working directory
print('Current working directory:', os.getcwd())

# %% [markdown]
# ## Load the pretrained MobileNet-SSD model
#
# MobileNet-SSD is a small ('mobile-friendly') Caffe model pretrained on the PASCAL VOC dataset (20 object classes). It needs two files, both downloadable directly:
# - `deploy.prototxt`: https://raw.githubusercontent.com/chuanqi305/MobileNet-SSD/master/deploy.prototxt
# - `mobilenet_iter_73000.caffemodel` (~23 MB): https://raw.githubusercontent.com/chuanqi305/MobileNet-SSD/master/mobilenet_iter_73000.caffemodel

# %%
# Download both model files (only needs to run once)


# Load the model with cv2.dnn.readNetFromCaffe

# %% [markdown]
# ## Read your image
#
# Find your own `.jpg` (e.g. via Google image search) containing 2-3 recognizable everyday objects.

# %%
# Download or copy your own image, then read it with cv2.imread


# Change the color to RGB (from BGR) for display later


# Plot the image

# %% [markdown]
# ## VOC class names
#
# MobileNet-SSD was pretrained on the PASCAL VOC dataset, which has 20 object classes.

# %%
VOC_CLASSES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat',
    'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant',
    'sheep', 'sofa', 'train', 'tvmonitor'
]
print(f'{len(VOC_CLASSES)} classes (including background)')

# %% [markdown]
# ## Object detection function
#
# Write a function `detect_objects(net, image, conf_threshold=0.4)` that:
# 1. Creates a blob from the image with `cv2.dnn.blobFromImage` — resize to 300x300,
#    scale factor `0.007843` (= 1/127.5), mean subtraction `127.5`
# 2. Sets the blob as input and runs a forward pass (`net.setInput`, `net.forward()`) —
#    the raw output has shape `(1, 1, num_detections, 7)`; each row is
#    `[image_id, class_id, confidence, x1, y1, x2, y2]` with box coordinates
#    normalized to `[0, 1]`
# 3. Loops over the detections, skipping any whose confidence is below `conf_threshold`
# 4. For the remaining detections: look up the class name in `VOC_CLASSES`, scale the
#    box coordinates back to the original image size (multiply by `[w, h, w, h]`), and
#    draw the box + label + confidence on a copy of the image (`cv2.rectangle`,
#    `cv2.putText`)
# 5. Returns the annotated image and a list of `(label, confidence)` tuples

# %%
def detect_objects(net, image, conf_threshold=0.4):
    h, w = image.shape[:2]

    # 1-2: blob, forward pass


    # 3-5: loop over detections, filter by confidence, scale boxes, draw, collect results

# %% [markdown]
# ## Run detection

# %%
# Run detect_objects on your image with conf_threshold=0.4, show the result and print
# the detections

# %% [markdown]
# **Image used:** *[which image did you use?]*
#
# **Detected objects (confidence threshold 0.4):** *[report the actual objects and confidence scores]*

# %% [markdown]
# ## Experiment with the confidence threshold
# Re-run detection with a few different thresholds of your choice (e.g. starting low, around the default 0.4, and quite high) and observe where the detections start changing.

# %%
# Loop over a few thresholds, run detect_objects for each, and print/plot the results

# %% [markdown]
# **Reflection:** *[describe, based on your own re-runs, how the number of detected (and false-positive) boxes changes as you vary the threshold]*

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
