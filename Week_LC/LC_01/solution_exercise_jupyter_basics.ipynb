# %% [markdown]
# ## Solutions exercises large classes (Week_01)

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import pandas as pd

# Settings
import warnings
warnings.filterwarnings("ignore")

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_LC/LC_01

# %% [markdown]
# ### Task 1: Cells and cell types

# %% [markdown]
# ## What I already know about Jupyter notebooks
# - A notebook is made of cells that can be either **code** or **markdown**
# - Cells are run with `Shift+Enter`, and each code cell can be run independently
# - All code cells in a notebook share one running Python process (the *kernel*)

# %% [markdown]
# <table>
#   <tr><th>Cell Type</th><th>Purpose</th></tr>
#   <tr><td>Code</td><td>Runs Python code</td></tr>
#   <tr><td>Markdown</td><td>Formatted text, headings, tables, images</td></tr>
# </table>

# %%
name = 'Heidi'
print(f'Welcome to Jupyter, {name}!')
# Out:
# Welcome to Jupyter, Heidi!

# %% [markdown]
# ### Task 2: Line magics: `%pwd`, `%who`, `%time`

# %%
# %pwd
# Out:
# '/workspaces/data_analytics/Week_LC/LC_01'

# %%
a = 10
b = [1, 2, 3]
c = 'jupyter'

# %who
# Out:
# a	 b	 c	 name	 os	 pd	 warnings

# %%
# %time 

squares = [i**2 for i in range(100_000)]
# Out:
# CPU times: user 4 μs, sys: 1 μs, total: 5 μs
# Wall time: 10.3 μs

# %% [markdown]
# ### Task 3: Cell magics: `%%time` and `%%writefile`

# %%
# %%time
total = 0
for i in range(1, 1_000_001):
    total += i
print('Sum:', total)
# Out:
# Sum: 500000500000
# CPU times: user 98.8 ms, sys: 839 μs, total: 99.7 ms
# Wall time: 109 ms

# %%
# %%writefile hello_jupyter.txt
# Hello from a Jupyter notebook cell magic!
# Out:
# Writing hello_jupyter.txt

# %%
# Read the file back with plain Python to confirm it was created
with open('hello_jupyter.txt', 'r') as f:
    print(f.read())

# Clean up the file created for this exercise
os.remove('hello_jupyter.txt')
# Out:
# Hello from a Jupyter notebook cell magic!

# %% [markdown]
# ### Task 4: Shell commands and getting help

# %%
# List the files in this folder (use !dir instead of !ls on Windows)
# !ls
# Out:
# Exercises_Large_Classes_Week_01.md  solution_exercise_jupyter_basics.ipynb

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %% [markdown]
# **Parameter I did not know about:** `read_csv` has a `usecols` parameter that lets you load only a subset of columns instead of the whole file, which saves memory and speeds up reading large files.

# %% [markdown]
# ### Task 5: Why cell order matters

# %% [markdown]
# **Observation:** Cells in a notebook share one running kernel, so a cell's output depends on which cells have *actually been run*, and in what order — not on their position in the notebook. If a `print(x)` cell were run *before* the cell defining `x = 1`, it would raise `NameError: name 'x' is not defined`, even though `x = 1` appears above it in the notebook. This is why, before trusting a notebook's outputs (or submitting it), you should use **Kernel → Restart Kernel and Run All Cells**: it guarantees every cell runs top-to-bottom in a fresh kernel, the same way a grader (or your future self) will run it.

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1064-azure
# Datetime: 2026-09-22 12:51:08
# Python Version: 3.11.16
# -----------------------------------
